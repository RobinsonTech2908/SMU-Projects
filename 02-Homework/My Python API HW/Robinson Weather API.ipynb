# %%
 # Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 627

# %%
# Starting URL for Weather Map API Call
#url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f2e7be3fbf6a6ca5ee22f83c7998246c"

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | koboldo
# City not found. Skipping...
# Processing Record 2 of Set 1 | songjianghe
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | hithadhoo
# Processing Record 5 of Set 1 | barrow
# Processing Record 6 of Set 1 | narsaq
# Processing Record 7 of Set 1 | avarua
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 1 | guerrero negro
# Processing Record 11 of Set 1 | gondar
# Processing Record 12 of Set 1 | faanui
# Processing Record 13 of Set 1 | yellowknife
# Processing Record 14 of Set 1 | mananjary
# Processing Record 15 of Set 1 | karkaralinsk
# City not found. Skipping...
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | kapustin yar
# Processing Record 18 of Set 1 | padang
# Processing Record 19 of Set 1 | thompson
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | arraial do cabo
# Processing Record 22 of Set 1 | kirksville
# Processing Record 23 of Set 1 | ostrovnoy
# Processing Record 24 of Set 1 | presidencia roque saenz pena
# Processing Record 25 of Set 1 | vila franca do campo
# Processing Record 26 of Set 1 | tasiilaq
# Processing Record 27 of Set 1 | mandalgovi
# Processing Record 28 of Set 1 | bethel
# Processing Record 29 of Set 1 | burica
# City not found. Skipping...
# Processing Record 30 of Set 1 | pisco
# Processing Record 31 of Set 1 | puerto boyaca
# Processing Record 32 of Set 1 | hasaki
# Processing Record 33 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 1 | geraldton
# Processing Record 35 of Set 1 | cabedelo
# Processing Record 36 of Set 1 | sao joao da barra
# Processing Record 37 of Set 1 | havoysund
# Processing Record 38 of Set 1 | ormara
# Processing Record 39 of Set 1 | dingle
# Processing Record 40 of Set 1 | grande-riviere
# City not found. Skipping...
# Processing Record 41 of Set 1 | pangnirtung
# Processing Record 42 of Set 1 | coahuayana
# Processing Record 43 of Set 1 | isangel
# Processing Record 44 of Set 1 | lata
# Processing Record 45 of Set 1 | gander
# Processing Record 46 of Set 1 | salalah
# Processing Record 47 of Set 1 | vila velha
# Processing Record 48 of Set 1 | bambous virieux
# Processing Record 49 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 1 | hilo
# Processing Record 0 of Set 2 | georgetown
# Processing Record 1 of Set 2 | hami
# Processing Record 2 of Set 2 | evensk
# Processing Record 3 of Set 2 | harper
# Processing Record 4 of Set 2 | bluff
# Processing Record 5 of Set 2 | bois-guillaume
# Processing Record 6 of Set 2 | chokurdakh
# Processing Record 7 of Set 2 | kununurra
# Processing Record 8 of Set 2 | puerto ayora
# Processing Record 9 of Set 2 | souillac
# Processing Record 10 of Set 2 | albany
# Processing Record 11 of Set 2 | rikitea
# Processing Record 12 of Set 2 | san jose
# Processing Record 13 of Set 2 | mangrol
# Processing Record 14 of Set 2 | upernavik
# Processing Record 15 of Set 2 | shujaabad
# Processing Record 16 of Set 2 | champerico
# Processing Record 17 of Set 2 | aquidauana
# Processing Record 18 of Set 2 | koulamoutou
# Processing Record 19 of Set 2 | hermanus
# Processing Record 20 of Set 2 | vaini
# Processing Record 21 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 2 | qaanaaq
# Processing Record 23 of Set 2 | plast
# Processing Record 24 of Set 2 | romanovka
# Processing Record 25 of Set 2 | port alfred
# Processing Record 26 of Set 2 | chastoozerye
# City not found. Skipping...
# Processing Record 27 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 2 | tiksi
# Processing Record 29 of Set 2 | namibe
# Processing Record 30 of Set 2 | krasnoselkup
# Processing Record 31 of Set 2 | kaitangata
# Processing Record 32 of Set 2 | henties bay
# Processing Record 33 of Set 2 | kavaratti
# Processing Record 34 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 2 | vorozhba
# Processing Record 36 of Set 2 | longhua
# Processing Record 37 of Set 2 | butaritari
# Processing Record 38 of Set 2 | kavieng
# Processing Record 39 of Set 2 | caconda
# Processing Record 40 of Set 2 | mount isa
# Processing Record 41 of Set 2 | mataura
# Processing Record 42 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 44 of Set 2 | ojinaga
# Processing Record 45 of Set 2 | the valley
# Processing Record 46 of Set 2 | saskylakh
# Processing Record 47 of Set 2 | kungalv
# Processing Record 48 of Set 2 | inuvik
# Processing Record 49 of Set 2 | sola
# Processing Record 0 of Set 3 | wakefield
# Processing Record 1 of Set 3 | nyakabindi
# Processing Record 2 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 3 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 3 | aksarka
# Processing Record 5 of Set 3 | leningradskiy
# Processing Record 6 of Set 3 | atuona
# Processing Record 7 of Set 3 | ballina
# Processing Record 8 of Set 3 | inderborskiy
# City not found. Skipping...
# Processing Record 9 of Set 3 | busselton
# Processing Record 10 of Set 3 | piacabucu
# Processing Record 11 of Set 3 | husavik
# Processing Record 12 of Set 3 | khatanga
# Processing Record 13 of Set 3 | meridian
# Processing Record 14 of Set 3 | gornopravdinsk
# Processing Record 15 of Set 3 | klaksvik
# Processing Record 16 of Set 3 | isetskoye
# Processing Record 17 of Set 3 | jamestown
# Processing Record 18 of Set 3 | atambua
# Processing Record 19 of Set 3 | ilulissat
# Processing Record 20 of Set 3 | ponta do sol
# Processing Record 21 of Set 3 | constitucion
# Processing Record 22 of Set 3 | kapaa
# Processing Record 23 of Set 3 | kahului
# Processing Record 24 of Set 3 | east london
# Processing Record 25 of Set 3 | praya
# Processing Record 26 of Set 3 | smithers
# Processing Record 27 of Set 3 | nalut
# Processing Record 28 of Set 3 | olafsvik
# Processing Record 29 of Set 3 | ye
# City not found. Skipping...
# Processing Record 30 of Set 3 | montlucon
# Processing Record 31 of Set 3 | lazaro cardenas
# Processing Record 32 of Set 3 | iqaluit
# Processing Record 33 of Set 3 | buckeye
# Processing Record 34 of Set 3 | chuy
# Processing Record 35 of Set 3 | grindavik
# Processing Record 36 of Set 3 | mercedes
# Processing Record 37 of Set 3 | sitka
# Processing Record 38 of Set 3 | karakol
# Processing Record 39 of Set 3 | kudymkar
# Processing Record 40 of Set 3 | mahebourg
# Processing Record 41 of Set 3 | nyrob
# Processing Record 42 of Set 3 | meulaboh
# Processing Record 43 of Set 3 | airai
# Processing Record 44 of Set 3 | vardo
# Processing Record 45 of Set 3 | carnarvon
# Processing Record 46 of Set 3 | zhitnevo
# Processing Record 47 of Set 3 | bathsheba
# Processing Record 48 of Set 3 | nikolskoye
# Processing Record 49 of Set 3 | dobryanka
# Processing Record 0 of Set 4 | casalmaggiore
# Processing Record 1 of Set 4 | vao
# Processing Record 2 of Set 4 | mtwara
# Processing Record 3 of Set 4 | cabo san lucas
# Processing Record 4 of Set 4 | ulladulla
# Processing Record 5 of Set 4 | adrar
# Processing Record 6 of Set 4 | sokoni
# Processing Record 7 of Set 4 | ribeira grande
# Processing Record 8 of Set 4 | lokosovo
# Processing Record 9 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 4 | provideniya
# Processing Record 11 of Set 4 | ust-nera
# Processing Record 12 of Set 4 | rojhan
# Processing Record 13 of Set 4 | hofn
# Processing Record 14 of Set 4 | dikson
# Processing Record 15 of Set 4 | srednekolymsk
# Processing Record 16 of Set 4 | hamina
# Processing Record 17 of Set 4 | ende
# Processing Record 18 of Set 4 | egvekinot
# Processing Record 19 of Set 4 | dillon
# Processing Record 20 of Set 4 | muzhi
# Processing Record 21 of Set 4 | colares
# Processing Record 22 of Set 4 | fairbanks
# Processing Record 23 of Set 4 | naze
# Processing Record 24 of Set 4 | kodiak
# Processing Record 25 of Set 4 | cockburn town
# Processing Record 26 of Set 4 | bay roberts
# Processing Record 27 of Set 4 | new norfolk
# Processing Record 28 of Set 4 | carauari
# Processing Record 29 of Set 4 | fez
# Processing Record 30 of Set 4 | lincoln
# Processing Record 31 of Set 4 | victoria
# Processing Record 32 of Set 4 | sumbawa
# City not found. Skipping...
# Processing Record 33 of Set 4 | chany
# Processing Record 34 of Set 4 | encruzilhada do sul
# Processing Record 35 of Set 4 | mombetsu
# Processing Record 36 of Set 4 | mount gambier
# Processing Record 37 of Set 4 | tuktoyaktuk
# Processing Record 38 of Set 4 | thongwa
# Processing Record 39 of Set 4 | ancud
# Processing Record 40 of Set 4 | norwich
# Processing Record 41 of Set 4 | severodvinsk
# Processing Record 42 of Set 4 | zhigansk
# Processing Record 43 of Set 4 | bacolod
# Processing Record 44 of Set 4 | stutterheim
# Processing Record 45 of Set 4 | kedougou
# Processing Record 46 of Set 4 | sechura
# Processing Record 47 of Set 4 | pombas
# Processing Record 48 of Set 4 | saint-philippe
# Processing Record 49 of Set 4 | kinablangan
# Processing Record 0 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 1 of Set 5 | sarankhola
# Processing Record 2 of Set 5 | garissa
# Processing Record 3 of Set 5 | opuwo
# Processing Record 4 of Set 5 | port elizabeth
# Processing Record 5 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 5 | tonj
# Processing Record 7 of Set 5 | cayenne
# Processing Record 8 of Set 5 | gulshat
# City not found. Skipping...
# Processing Record 9 of Set 5 | nemuro
# Processing Record 10 of Set 5 | biskamzha
# Processing Record 11 of Set 5 | linfen
# Processing Record 12 of Set 5 | beloha
# Processing Record 13 of Set 5 | fort nelson
# Processing Record 14 of Set 5 | codrington
# Processing Record 15 of Set 5 | aksay
# Processing Record 16 of Set 5 | lima
# Processing Record 17 of Set 5 | nova olimpia
# Processing Record 18 of Set 5 | sambava
# Processing Record 19 of Set 5 | monroe
# Processing Record 20 of Set 5 | saltillo
# Processing Record 21 of Set 5 | mehamn
# Processing Record 22 of Set 5 | kostroma
# Processing Record 23 of Set 5 | biankouma
# Processing Record 24 of Set 5 | zhifang
# Processing Record 25 of Set 5 | taburi
# City not found. Skipping...
# Processing Record 26 of Set 5 | batabano
# Processing Record 27 of Set 5 | behbahan
# Processing Record 28 of Set 5 | jackson
# Processing Record 29 of Set 5 | cururupu
# Processing Record 30 of Set 5 | tezu
# Processing Record 31 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 5 | broome
# Processing Record 33 of Set 5 | uglovskoye
# Processing Record 34 of Set 5 | norman wells
# Processing Record 35 of Set 5 | west plains
# Processing Record 36 of Set 5 | berlevag
# Processing Record 37 of Set 5 | ferrol
# Processing Record 38 of Set 5 | asau
# Processing Record 39 of Set 5 | marabba
# Processing Record 40 of Set 5 | kruisfontein
# Processing Record 41 of Set 5 | flinders
# Processing Record 42 of Set 5 | cape town
# Processing Record 43 of Set 5 | marsa matruh
# Processing Record 44 of Set 5 | manokwari
# Processing Record 45 of Set 5 | ishigaki
# Processing Record 46 of Set 5 | marawi
# Processing Record 47 of Set 5 | cidreira
# Processing Record 48 of Set 5 | koror
# Processing Record 49 of Set 5 | yefira
# City not found. Skipping...
# Processing Record 0 of Set 6 | shymkent
# Processing Record 1 of Set 6 | lebu
# Processing Record 2 of Set 6 | nouadhibou
# Processing Record 3 of Set 6 | sibu
# Processing Record 4 of Set 6 | dunedin
# Processing Record 5 of Set 6 | itoman
# Processing Record 6 of Set 6 | djambala
# Processing Record 7 of Set 6 | bella union
# Processing Record 8 of Set 6 | hualmay
# Processing Record 9 of Set 6 | novyy urgal
# Processing Record 10 of Set 6 | palmer
# Processing Record 11 of Set 6 | alexandria
# Processing Record 12 of Set 6 | baishishan
# Processing Record 13 of Set 6 | porbandar
# Processing Record 14 of Set 6 | tabou
# Processing Record 15 of Set 6 | tocopilla
# Processing Record 16 of Set 6 | manuk mangkaw
# Processing Record 17 of Set 6 | acarau
# Processing Record 18 of Set 6 | vylok
# Processing Record 19 of Set 6 | ixtapa
# Processing Record 20 of Set 6 | te anau
# Processing Record 21 of Set 6 | minusinsk
# Processing Record 22 of Set 6 | rio de jesus
# Processing Record 23 of Set 6 | rio grande
# Processing Record 24 of Set 6 | bontang
# Processing Record 25 of Set 6 | ketrzyn
# Processing Record 26 of Set 6 | zhanaozen
# Processing Record 27 of Set 6 | gunjur
# Processing Record 28 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 29 of Set 6 | auki
# Processing Record 30 of Set 6 | paidha
# Processing Record 31 of Set 6 | tiznit
# Processing Record 32 of Set 6 | sita buzaului
# Processing Record 33 of Set 6 | kharp
# Processing Record 34 of Set 6 | hollola
# Processing Record 35 of Set 6 | mar del plata
# Processing Record 36 of Set 6 | castro
# Processing Record 37 of Set 6 | soe
# Processing Record 38 of Set 6 | makinsk
# Processing Record 39 of Set 6 | saint george
# Processing Record 40 of Set 6 | datong
# Processing Record 41 of Set 6 | nacala
# Processing Record 42 of Set 6 | ascension
# Processing Record 43 of Set 6 | bosaso
# Processing Record 44 of Set 6 | oistins
# Processing Record 45 of Set 6 | beira
# Processing Record 46 of Set 6 | somova
# Processing Record 47 of Set 6 | katsuura
# Processing Record 48 of Set 6 | pevek
# Processing Record 49 of Set 6 | kargasok
# Processing Record 0 of Set 7 | bukama
# Processing Record 1 of Set 7 | floro
# Processing Record 2 of Set 7 | katobu
# Processing Record 3 of Set 7 | jaguaribe
# Processing Record 4 of Set 7 | nanortalik
# Processing Record 5 of Set 7 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 6 of Set 7 | los llanos de aridane
# Processing Record 7 of Set 7 | caravelas
# Processing Record 8 of Set 7 | lethem
# Processing Record 9 of Set 7 | torbay
# Processing Record 10 of Set 7 | lexington
# Processing Record 11 of Set 7 | bwanga
# Processing Record 12 of Set 7 | les escoumins
# Processing Record 13 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 7 | zeya
# Processing Record 15 of Set 7 | la libertad
# Processing Record 16 of Set 7 | tubruq
# City not found. Skipping...
# Processing Record 17 of Set 7 | severo-yeniseyskiy
# Processing Record 18 of Set 7 | comodoro rivadavia
# Processing Record 19 of Set 7 | turka
# Processing Record 20 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 21 of Set 7 | vallenar
# Processing Record 22 of Set 7 | haines junction
# Processing Record 23 of Set 7 | beringovskiy
# Processing Record 24 of Set 7 | prince rupert
# Processing Record 25 of Set 7 | mnogovershinnyy
# Processing Record 26 of Set 7 | richards bay
# Processing Record 27 of Set 7 | keti bandar
# Processing Record 28 of Set 7 | banda aceh
# Processing Record 29 of Set 7 | clyde river
# Processing Record 30 of Set 7 | nuevo progreso
# Processing Record 31 of Set 7 | qaqortoq
# Processing Record 32 of Set 7 | rock springs
# Processing Record 33 of Set 7 | emerald
# Processing Record 34 of Set 7 | rustenburg
# Processing Record 35 of Set 7 | kempsey
# Processing Record 36 of Set 7 | marau
# Processing Record 37 of Set 7 | tazovskiy
# Processing Record 38 of Set 7 | aklavik
# Processing Record 39 of Set 7 | coquimbo
# Processing Record 40 of Set 7 | komsomolskiy
# Processing Record 41 of Set 7 | samarai
# Processing Record 42 of Set 7 | hobyo
# Processing Record 43 of Set 7 | baykalovo
# Processing Record 44 of Set 7 | kuito
# Processing Record 45 of Set 7 | ondo
# Processing Record 46 of Set 7 | sept-iles
# Processing Record 47 of Set 7 | valley station
# Processing Record 48 of Set 7 | ustyuzhna
# Processing Record 49 of Set 7 | hedaru
# Processing Record 0 of Set 8 | port blair
# Processing Record 1 of Set 8 | mancio lima
# Processing Record 2 of Set 8 | krasnogvardeyskiy
# Processing Record 3 of Set 8 | khani
# Processing Record 4 of Set 8 | mingoyo
# Processing Record 5 of Set 8 | paramonga
# Processing Record 6 of Set 8 | kenai
# Processing Record 7 of Set 8 | dibulla
# Processing Record 8 of Set 8 | boyolangu
# Processing Record 9 of Set 8 | awash
# Processing Record 10 of Set 8 | kuryk
# Processing Record 11 of Set 8 | abong mbang
# Processing Record 12 of Set 8 | vostok
# Processing Record 13 of Set 8 | cairns
# Processing Record 14 of Set 8 | svetlyy
# Processing Record 15 of Set 8 | talnakh
# Processing Record 16 of Set 8 | la ronge
# Processing Record 17 of Set 8 | bousso
# Processing Record 18 of Set 8 | grand gaube
# Processing Record 19 of Set 8 | sorland
# Processing Record 20 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 21 of Set 8 | yerbogachen
# Processing Record 22 of Set 8 | carutapera
# Processing Record 23 of Set 8 | wooster
# Processing Record 24 of Set 8 | yermakovskoye
# Processing Record 25 of Set 8 | ibanda
# Processing Record 26 of Set 8 | alice
# Processing Record 27 of Set 8 | tautira
# Processing Record 28 of Set 8 | karpathos
# Processing Record 29 of Set 8 | cap malheureux
# Processing Record 30 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 8 | odweyne
# Processing Record 32 of Set 8 | fonte boa
# Processing Record 33 of Set 8 | lorengau
# Processing Record 34 of Set 8 | santiago
# Processing Record 35 of Set 8 | port hedland
# Processing Record 36 of Set 8 | hede
# Processing Record 37 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 38 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 8 | gdov
# Processing Record 40 of Set 8 | yulara
# Processing Record 41 of Set 8 | arawa
# Processing Record 42 of Set 8 | esperance
# Processing Record 43 of Set 8 | japura
# Processing Record 44 of Set 8 | sisimiut
# Processing Record 45 of Set 8 | punta cardon
# Processing Record 46 of Set 8 | jiwani
# Processing Record 47 of Set 8 | mareeba
# Processing Record 48 of Set 8 | san patricio
# Processing Record 49 of Set 8 | pietarsaari
# Processing Record 0 of Set 9 | pimentel
# Processing Record 1 of Set 9 | sioux lookout
# Processing Record 2 of Set 9 | punta gorda
# Processing Record 3 of Set 9 | naryan-mar
# Processing Record 4 of Set 9 | arman
# Processing Record 5 of Set 9 | pakxan
# Processing Record 6 of Set 9 | port keats
# Processing Record 7 of Set 9 | daye
# Processing Record 8 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 9 of Set 9 | ahtopol
# Processing Record 10 of Set 9 | ahuimanu
# Processing Record 11 of Set 9 | gorontalo
# Processing Record 12 of Set 9 | diffa
# Processing Record 13 of Set 9 | marsh harbour
# Processing Record 14 of Set 9 | gigmoto
# Processing Record 15 of Set 9 | lagoa
# Processing Record 16 of Set 9 | camana
# Processing Record 17 of Set 9 | half moon bay
# Processing Record 18 of Set 9 | whitianga
# Processing Record 19 of Set 9 | magnolia
# Processing Record 20 of Set 9 | multai
# Processing Record 21 of Set 9 | wanning
# Processing Record 22 of Set 9 | atar
# Processing Record 23 of Set 9 | matara
# Processing Record 24 of Set 9 | sao felix do xingu
# Processing Record 25 of Set 9 | juba
# Processing Record 26 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 27 of Set 9 | kolchugino
# Processing Record 28 of Set 9 | chapais
# Processing Record 29 of Set 9 | itarema
# Processing Record 30 of Set 9 | baykit
# Processing Record 31 of Set 9 | weihai
# Processing Record 32 of Set 9 | manyana
# Processing Record 33 of Set 9 | huambo
# Processing Record 34 of Set 9 | cordoba
# Processing Record 35 of Set 9 | nantucket
# Processing Record 36 of Set 9 | rawson
# Processing Record 37 of Set 9 | sibolga
# Processing Record 38 of Set 9 | tumut
# Processing Record 39 of Set 9 | areka
# Processing Record 40 of Set 9 | qasigiannguit
# Processing Record 41 of Set 9 | pilao arcado
# City not found. Skipping...
# Processing Record 42 of Set 9 | longyearbyen
# Processing Record 43 of Set 9 | merced
# Processing Record 44 of Set 9 | san quintin
# Processing Record 45 of Set 9 | chara
# Processing Record 46 of Set 9 | touros
# Processing Record 47 of Set 9 | olinda
# Processing Record 48 of Set 9 | kiruna
# Processing Record 49 of Set 9 | chililabombwe
# Processing Record 0 of Set 10 | najran
# Processing Record 1 of Set 10 | lavrentiya
# Processing Record 2 of Set 10 | bengkulu
# Processing Record 3 of Set 10 | aanekoski
# Processing Record 4 of Set 10 | saldanha
# Processing Record 5 of Set 10 | tra vinh
# Processing Record 6 of Set 10 | vega de alatorre
# Processing Record 7 of Set 10 | bonavista
# Processing Record 8 of Set 10 | beidao
# Processing Record 9 of Set 10 | takoradi
# Processing Record 10 of Set 10 | saint anthony
# Processing Record 11 of Set 10 | kazachinskoye
# Processing Record 12 of Set 10 | namikupa
# Processing Record 13 of Set 10 | maunabo
# Processing Record 14 of Set 10 | new milford
# Processing Record 15 of Set 10 | fortuna
# Processing Record 16 of Set 10 | mutoko
# Processing Record 17 of Set 10 | kyabe
# Processing Record 18 of Set 10 | bilma
# Processing Record 19 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 10 | maku
# Processing Record 21 of Set 10 | denizli
# Processing Record 22 of Set 10 | salinas
# Processing Record 23 of Set 10 | shellbrook
# Processing Record 24 of Set 10 | abu samrah
# Processing Record 25 of Set 10 | fukue
# Processing Record 26 of Set 10 | ruteng
# Processing Record 27 of Set 10 | laguna
# Processing Record 28 of Set 10 | christiana
# Processing Record 29 of Set 10 | osmena
# Processing Record 30 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 31 of Set 10 | tripoli
# Processing Record 32 of Set 10 | jiuquan
# Processing Record 33 of Set 10 | platanos
# Processing Record 34 of Set 10 | umm kaddadah
# Processing Record 35 of Set 10 | rupert
# Processing Record 36 of Set 10 | vung tau
# Processing Record 37 of Set 10 | pacific grove
# Processing Record 38 of Set 10 | sayyan
# Processing Record 39 of Set 10 | zhezkazgan
# Processing Record 40 of Set 10 | cherskiy
# Processing Record 41 of Set 10 | whakatane
# Processing Record 42 of Set 10 | ornes
# Processing Record 43 of Set 10 | gravdal
# Processing Record 44 of Set 10 | parfenyevo
# Processing Record 45 of Set 10 | chik
# Processing Record 46 of Set 10 | oshnaviyeh
# Processing Record 47 of Set 10 | sinnamary
# Processing Record 48 of Set 10 | ramhormoz
# Processing Record 49 of Set 10 | kamenka
# Processing Record 0 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 1 of Set 11 | tairua
# Processing Record 2 of Set 11 | horconcitos
# Processing Record 3 of Set 11 | khasan
# Processing Record 4 of Set 11 | nome
# Processing Record 5 of Set 11 | aykhal
# Processing Record 6 of Set 11 | rio gallegos
# Processing Record 7 of Set 11 | aljezur
# Processing Record 8 of Set 11 | korem
# Processing Record 9 of Set 11 | yumbo
# Processing Record 10 of Set 11 | cartagena del chaira
# Processing Record 11 of Set 11 | kimberley
# Processing Record 12 of Set 11 | road town
# Processing Record 13 of Set 11 | tabuk
# Processing Record 14 of Set 11 | photharam
# Processing Record 15 of Set 11 | kuusamo
# Processing Record 16 of Set 11 | dahra
# Processing Record 17 of Set 11 | namatanai
# Processing Record 18 of Set 11 | rena
# Processing Record 19 of Set 11 | abbeville
# Processing Record 20 of Set 11 | tumpat
# Processing Record 21 of Set 11 | maicao
# Processing Record 22 of Set 11 | walvis bay
# Processing Record 23 of Set 11 | deputatskiy
# Processing Record 24 of Set 11 | talavera de la reina
# Processing Record 25 of Set 11 | nador
# Processing Record 26 of Set 11 | bilibino
# Processing Record 27 of Set 11 | amboasary
# Processing Record 28 of Set 11 | ahipara
# Processing Record 29 of Set 11 | newport
# Processing Record 30 of Set 11 | ternate
# Processing Record 31 of Set 11 | salvador
# Processing Record 32 of Set 11 | cayce
# Processing Record 33 of Set 11 | havre
# Processing Record 34 of Set 11 | del rio
# Processing Record 35 of Set 11 | dongsheng
# Processing Record 36 of Set 11 | seoul
# Processing Record 37 of Set 11 | nuziders
# Processing Record 38 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 39 of Set 11 | kristianstad
# Processing Record 40 of Set 11 | raga
# Processing Record 41 of Set 11 | yazman
# Processing Record 42 of Set 11 | binzhou
# Processing Record 43 of Set 11 | sorochinsk
# Processing Record 44 of Set 11 | lubao
# Processing Record 45 of Set 11 | pochutla
# Processing Record 46 of Set 11 | faya
# Processing Record 47 of Set 11 | pirgos
# Processing Record 48 of Set 11 | claremore
# Processing Record 49 of Set 11 | jasdan
# Processing Record 0 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 12 | brae
# Processing Record 2 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 12 | lebedinyy
# Processing Record 4 of Set 12 | christchurch
# Processing Record 5 of Set 12 | abha
# Processing Record 6 of Set 12 | nyimba
# Processing Record 7 of Set 12 | sidney
# Processing Record 8 of Set 12 | jibuti
# Processing Record 9 of Set 12 | salinopolis
# Processing Record 10 of Set 12 | hanmer springs
# Processing Record 11 of Set 12 | alofi
# Processing Record 12 of Set 12 | aksu
# Processing Record 13 of Set 12 | vasterhaninge
# Processing Record 14 of Set 12 | calama
# Processing Record 15 of Set 12 | arkadelphia
# Processing Record 16 of Set 12 | nehe
# Processing Record 17 of Set 12 | weihe
# Processing Record 18 of Set 12 | turayf
# Processing Record 19 of Set 12 | waingapu
# Processing Record 20 of Set 12 | maidstone
# Processing Record 21 of Set 12 | luwuk
# Processing Record 22 of Set 12 | mayumba
# Processing Record 23 of Set 12 | bridgetown
# Processing Record 24 of Set 12 | ponta delgada
# Processing Record 25 of Set 12 | ushtobe
# Processing Record 26 of Set 12 | port hope
# Processing Record 27 of Set 12 | tomatlan
# Processing Record 28 of Set 12 | xai-xai
# Processing Record 29 of Set 12 | urfa
# City not found. Skipping...
# Processing Record 30 of Set 12 | bara
# Processing Record 31 of Set 12 | sergeyevka
# Processing Record 32 of Set 12 | vestmannaeyjar
# Processing Record 33 of Set 12 | kampot
# Processing Record 34 of Set 12 | glyadyanskoye
# Processing Record 35 of Set 12 | zabid
# Processing Record 36 of Set 12 | baturaja
# Processing Record 37 of Set 12 | santa barbara
# Processing Record 38 of Set 12 | severo-kurilsk
# Processing Record 39 of Set 12 | farah
# Processing Record 40 of Set 12 | yarada
# Processing Record 41 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 12 | cam ranh
# Processing Record 43 of Set 12 | macapa
# Processing Record 44 of Set 12 | burlington
# Processing Record 45 of Set 12 | aviemore
# Processing Record 46 of Set 12 | tres lagoas
# Processing Record 47 of Set 12 | saint-georges
# Processing Record 48 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 12 | vilcun
# Processing Record 0 of Set 13 | mangan
# Processing Record 1 of Set 13 | praia
# Processing Record 2 of Set 13 | indramayu
# Processing Record 3 of Set 13 | bere
# Processing Record 4 of Set 13 | high level
# Processing Record 5 of Set 13 | mpanda
# Processing Record 6 of Set 13 | kamina
# Processing Record 7 of Set 13 | miranorte
# City not found. Skipping...
# Processing Record 8 of Set 13 | srandakan
# Processing Record 9 of Set 13 | poum
# Processing Record 10 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 11 of Set 13 | asyut
# Processing Record 12 of Set 13 | mubende
# Processing Record 13 of Set 13 | novyy urengoy
# Processing Record 14 of Set 13 | evanston
# Processing Record 15 of Set 13 | lira
# Processing Record 16 of Set 13 | synya
# Processing Record 17 of Set 13 | ati
# Processing Record 18 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 19 of Set 13 | coihaique
# Processing Record 20 of Set 13 | awjilah
# Processing Record 21 of Set 13 | port hardy
# Processing Record 22 of Set 13 | creston
# Processing Record 23 of Set 13 | wagar
# Processing Record 24 of Set 13 | ninohe
# Processing Record 25 of Set 13 | teguise
# Processing Record 26 of Set 13 | phuket
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)

# Show Record Count
city_data_pd.count()
# Out:
# City          579
# Lat           579
# Lng           579
# Max Temp      579
# Humidity      579
# Cloudiness    579
# Wind Speed    579
# Country       579
# Date          579
# dtype: int64

# %%
# Display the City Data Frame
city_data_pd.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  songjianghe  42.1859  127.4790     28.54        97         100        3.56
# 1      ushuaia -54.8000  -68.3000     46.40        61          75       21.85
# 2    hithadhoo  -0.6000   73.0833     80.80        74         100        3.62
# 3       barrow  71.2906 -156.7887     -5.80        84          40       12.66
# 4       narsaq  60.9167  -46.0500     24.80        26          54       27.63
#
#   Country        Date
# 0      CN  1611625257
# 1      AR  1611624933
# 2      MV  1611624923
# 3      US  1611624920
# 4      GL  1611624750

# %%
city_data_pd.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  579.000000  579.000000  579.000000  579.000000  579.000000  579.000000
# mean    20.634267   18.185470   49.177444   74.913644   57.291883    8.203903
# std     33.058768   88.284293   32.501791   18.875649   40.129498    6.175539
# min    -54.800000 -179.166700  -56.110000   19.000000    0.000000    0.380000
# 25%     -5.723750  -59.575000   30.165000   65.000000   20.000000    3.515000
# 50%     22.308200   26.066700   61.050000   79.000000   75.000000    6.890000
# 75%     48.809050   93.158450   75.020000   88.000000   98.000000   11.340000
# max     78.218600  179.316700  100.400000  100.000000  100.000000   36.600000
#
#                Date
# count  5.790000e+02
# mean   1.611625e+09
# std    1.888126e+02
# min    1.611625e+09
# 25%    1.611625e+09
# 50%    1.611625e+09
# 75%    1.611625e+09
# max    1.611625e+09

# %%
dirty_city_data = city_data_pd[(city_data_pd["Humidity"] > 100)].index
                                  
dirty_city_data
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = city_data_pd.drop(dirty_city_data, inplace=False)
clean_city_data.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  songjianghe  42.1859  127.4790     28.54        97         100        3.56
# 1      ushuaia -54.8000  -68.3000     46.40        61          75       21.85
# 2    hithadhoo  -0.6000   73.0833     80.80        74         100        3.62
# 3       barrow  71.2906 -156.7887     -5.80        84          40       12.66
# 4       narsaq  60.9167  -46.0500     24.80        26          54       27.63
#
#   Country        Date
# 0      CN  1611625257
# 1      AR  1611624933
# 2      MV  1611624923
# 3      US  1611624920
# 4      GL  1611624750

# %%
# Extract relevant fields from the data frame
lats = clean_city_data["Lat"]
max_temps = clean_city_data["Max Temp"]
humidity = clean_city_data["Humidity"]
cloudiness = clean_city_data["Cloudiness"]
wind_speed = clean_city_data["Wind Speed"]

# Export the City_Data into a csv
clean_city_data.to_csv(output_data_file, index_label="City_ID")

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(lats, 
            max_temps,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(lats, 
            humidity,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(lats, 
            cloudiness,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(lats, 
            wind_speed,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %%
# Create a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    # Run regresson on southern hemisphere
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(title)
    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] >= 0)]
southern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] < 0)]

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp',(6,30))
# Out:
# The r-value is: 0.7213147082931205

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp', (-55, 90))
# Out:
# The r-value is: 0.06521884954046864

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity',(40,10))
# Out:
# The r-value is: 0.15096201807314708

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity', (-50, 20))
# Out:
# The r-value is: 0.22412200419110181

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness', (40,10))
# Out:
# The r-value is: 0.09796379588655514

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness', (-30,30))
# Out:
# The r-value is: 0.18683641959216063

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed', (40,25))
# Out:
# The r-value is: 0.013151440252966157

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed', (-50, 20))
# Out:
# The r-value is: 0.1967836163970442
